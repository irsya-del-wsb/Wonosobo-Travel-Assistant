# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_community.vectorstores import Chroma

import os
from dotenv import load_dotenv

load_dotenv()
pdf_files = [
    "data/Wisata_Wonosobo_Panduan.pdf",
    "data/Kuliner_Wonosobo_Panduan.pdf",
    "data/Hotel_Wonosobo_Panduan.pdf"
]

documents = []

for pdf in pdf_files:
    loader = PyPDFLoader(pdf)
    documents.extend(loader.load())

print(f"Total halaman: {len(documents)}")
# Out:
# C:\Users\irsya\AppData\Local\Temp\ipykernel_22572\4171686945.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader
# Total halaman: 11

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

chunks = text_splitter.split_documents(documents)

print(len(chunks))
# Out:
# 21

# %%
embeddings = GoogleGenerativeAIEmbeddings(
    model="models/gemini-embedding-001"
)

vectorstore = Chroma.from_documents(
    documents=chunks,
    embedding=embeddings,
    persist_directory="chroma_db"
)

print("Vector DB berhasil dibuat")
# Out:
# Vector DB berhasil dibuat
